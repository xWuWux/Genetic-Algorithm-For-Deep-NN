# %% [markdown]
# <a href="https://colab.research.google.com/github/Francja/geneticAlgorithm/blob/master/Genetic_algorithm_for_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import pandas as pd
from random import random
from random import randint
from random import shuffle

# Length of table, how many layers would neural network have (min. 2)
MIN_LAYER = 2
MAX_LAYER = 3
# Max value of element in table, max neurons in each layer
MAX_NEURONS = 5
# Population of individuals, needs to be dividable by 4.
POPULATION = 8
# How many iterations will the algorithm go through
GENERATIONS = 3
# Target score, after it's accomplished algorithm stops
TARGET_SCORE = 0.5
# Mutation chance - it's applied to each individual in each generation
MUTATION_CHANCE = 0.01
# Number of generations without change in score after the algorithm will stop
NO_EVOLVE_GENS = 3

CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']


def generate_individual():
    new_ind = []
    layers = randint(MIN_LAYER, MAX_LAYER)
    for n in range(0, layers):
            new_ind.append(randint(1, MAX_NEURONS))
    return new_ind


def initialize():
    pop = []
    for n in range(0, POPULATION):
        pop.append(generate_individual())
    return pop


def cost(ind):
    #c = (ind[0]*ind[-1])
    c = DNN(ind)
    return c


def sort(pop_with_cost):
    pop_with_cost.sort(key=lambda x: x[1])
    return pop_with_cost


def roulette(pop_with_cost):
    cost_sum = sum(n for _, n in pop_with_cost)

    cost_table = []
    for ind in pop_with_cost:
        cost_table.append(ind[1])

    rel_cost = [cost_ind / cost_sum for cost_ind in cost_table]
    probability = [sum(rel_cost[:i + 1]) for i in range(len(rel_cost))]

    new_pop = []
    for n in range(POPULATION//2):
        r = random()
        for (i, individual) in enumerate(pop_with_cost):
            if r <= probability[i]:
                new_pop.append(individual)
                break
    return new_pop


def cross_parents(parent1, parent2, cross_point):
    child = []
    child.extend(parent1[:cross_point])
    child.extend(parent2[cross_point:])
    return child


def crossover(pop):
    random_index_table = []

    for x in range(0, len(pop)):
        random_index_table.append(x)
    shuffle(random_index_table)

    for x in range(0, len(pop), 2):
        p1 = pop[random_index_table[x]][0]
        p2 = pop[random_index_table[x+1]][0]
        max_cross_point = min(len(p1), len(p2)) - 1
        cross_point = randint(1, max_cross_point)
        pop.append(cross_parents(p1, p2, cross_point))
        pop.append(cross_parents(p2, p1, cross_point))
    return pop


def calculate_missing_cost(pop):
    pop_with_scores = []
    for ind in pop:
        if isinstance(ind[0], list):
            pop_with_scores.append(ind)
        else:
            pop_with_scores.append([ind, cost(ind)])
    return pop_with_scores


def mutate(pop):
    mutated_pop = []
    for ind in pop:
        rand = random()
        if rand <= MUTATION_CHANCE:
            rand2 = randint(0, 100)
            mut_value = 1 if rand2 % 2 == 0 else -1
            if isinstance(ind[0], list):  # individual has cost:
                target_cell = randint(0, len(ind[0]) - 1)
                new_value = ind[0][target_cell] + mut_value
                new_value = 1 if new_value > MAX_NEURONS else new_value
                new_value = MAX_NEURONS if new_value == 0 else new_value
                ind[0][target_cell] = new_value
                mutated_pop.append(ind[0])  # so the cost function will be cleared
            else:
                target_cell = randint(0, len(ind) - 1)
                new_value = ind[target_cell] + mut_value
                new_value = 1 if new_value > MAX_NEURONS else new_value
                new_value = MAX_NEURONS if new_value == 0 else new_value
                ind[target_cell] = new_value
                mutated_pop.append(ind)
        else:
            mutated_pop.append(ind)
    return mutated_pop


def gather_text(pop, g, best, text):
    pop.sort(key=lambda x: x[1], reverse=True)
    t = f"Generation {g + 1} ~~ best score = {round(best, 2)}\n"
    for n in range(0, 5):
        text = f"#{5 - n}: {pop[4-n][0]}; \tscore: {round(pop[4-n][1], 2)}\n" + text
    text = t + text + t
    return text


def final_text(stop, text):
    print(text)
    if stop == "success":
        print(f"SUCCESS: Target of score of {TARGET_SCORE} was accomplished.")
    elif stop == "stagnation":
        print(f"FAILED: Population stopped evolving.")
    else:
        print("FAILED: Target was not accomplished.")


def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)


def DNN(population_for_DNN):
    #Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
    classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units = population_for_DNN,
    # The model must choose between 3 classes.
    n_classes=3)

    classifier.train(
        input_fn=lambda: input_fn(train, train_y, training=True),
        steps=5000)
      
    # We include a lambda to avoid creating an inner function previously

    eval_result = classifier.evaluate(
        input_fn=lambda: input_fn(test, test_y, training=False))

    print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
    print(eval_result)
    print('\n \n')
    print(dict(list(eval_result.items())[0:3]))
    print(classifier.train)
    print('\n \n')
    print(tf.losses.Reduction)
    print(f"hidden_units")
    return(eval_result.get('accuracy'))


if __name__ == "__main__" and MIN_LAYER >= 2 and POPULATION % 4 == 0:

    train_path = tf.keras.utils.get_file(
        "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
    test_path = tf.keras.utils.get_file(
        "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")
    train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
    test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
    stop_condition = ""
    text_summary = ""
    pop_bag = []

    # train DNN 
    train.head()
    train_y = train.pop('Species')
    test_y = test.pop('Species')
    train.head() # the species column is now gone
    train.shape  # we have 120 entires with 4 features

    # Feature columns describe how to use the input.
    my_feature_columns = []
    for key in train.keys():
        my_feature_columns.append(tf.feature_column.numeric_column(key=key))

    # creates the initial randomized population bag:
    init_pop_bag = initialize()

    # initial pop go through neural network and setting the score:
    for init_ind in init_pop_bag:
        pop_bag.append([init_ind, cost(init_ind)])

    # creates places to gather scores
    best_of_gen = max(pop_bag, key=lambda x: x[1])[1]
    max_score = best_of_gen
    score_table = [best_of_gen]

    # loop that goes through rest of generations:
    for gen in range(0, GENERATIONS):

        text_summary = gather_text(pop_bag, gen, best_of_gen, text_summary)

        #checks if generations maximum was better that top score
        if max_score <= best_of_gen:
            max_score = best_of_gen

        # stop condition check
        if max_score >= TARGET_SCORE:
            stop_condition = "success"
            break

        # checks if the population stopped evolving
        if score_table[-NO_EVOLVE_GENS:].count(score_table[-1]) >= NO_EVOLVE_GENS:
            stop_condition = "stagnation"
            break

        # choosing new population based on roulette
        pop_bag = roulette(pop_bag)

        # crossover of randomly selected parents
        pop_bag = crossover(pop_bag)

        # mutating
        pop_bag = mutate(pop_bag)

        # calculating score for new children and mutated ones
        pop_bag = calculate_missing_cost(pop_bag)

        # getting best score of generation
        best_of_gen = max(pop_bag, key=lambda x: x[1])[1]
        score_table.append(best_of_gen)

    final_text(pop_bag, text_summary))

else:
    print("Please correct POPULATION or MIN_LAYER")
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # this line is not required unless you are in a notebook`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpp7s9qsrk
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpp7s9qsrk', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpp7s9qsrk/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 2.8261933, step = 0
# INFO:tensorflow:global_step/sec: 473.998
# INFO:tensorflow:loss = 2.2118342, step = 100 (0.213 sec)
# INFO:tensorflow:global_step/sec: 583.321
# INFO:tensorflow:loss = 1.9567918, step = 200 (0.172 sec)
# INFO:tensorflow:global_step/sec: 607.26
# INFO:tensorflow:loss = 1.6984336, step = 300 (0.167 sec)
# INFO:tensorflow:global_step/sec: 640.495
# INFO:tensorflow:loss = 1.651983, step = 400 (0.158 sec)
# INFO:tensorflow:global_step/sec: 534.291
# INFO:tensorflow:loss = 1.4747818, step = 500 (0.185 sec)
# INFO:tensorflow:global_step/sec: 560.18
# INFO:tensorflow:loss = 1.4433734, step = 600 (0.176 sec)
# INFO:tensorflow:global_step/sec: 605.747
# INFO:tensorflow:loss = 1.3911711, step = 700 (0.165 sec)
# INFO:tensorflow:global_step/sec: 649.933
# INFO:tensorflow:loss = 1.3326526, step = 800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 607.088
# INFO:tensorflow:loss = 1.2972422, step = 900 (0.164 sec)
# INFO:tensorflow:global_step/sec: 597.327
# INFO:tensorflow:loss = 1.2642417, step = 1000 (0.167 sec)
# INFO:tensorflow:global_step/sec: 607.705
# INFO:tensorflow:loss = 1.2375343, step = 1100 (0.162 sec)
# INFO:tensorflow:global_step/sec: 606.562
# INFO:tensorflow:loss = 1.2218945, step = 1200 (0.168 sec)
# INFO:tensorflow:global_step/sec: 582.59
# INFO:tensorflow:loss = 1.2089875, step = 1300 (0.168 sec)
# INFO:tensorflow:global_step/sec: 586.606
# INFO:tensorflow:loss = 1.1875186, step = 1400 (0.170 sec)
# INFO:tensorflow:global_step/sec: 590.587
# INFO:tensorflow:loss = 1.1788557, step = 1500 (0.172 sec)
# INFO:tensorflow:global_step/sec: 585.897
# INFO:tensorflow:loss = 1.1697863, step = 1600 (0.168 sec)
# INFO:tensorflow:global_step/sec: 609.276
# INFO:tensorflow:loss = 1.1622239, step = 1700 (0.167 sec)
# INFO:tensorflow:global_step/sec: 616.958
# INFO:tensorflow:loss = 1.1582191, step = 1800 (0.162 sec)
# INFO:tensorflow:global_step/sec: 619.3
# INFO:tensorflow:loss = 1.1447637, step = 1900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 613.659
# INFO:tensorflow:loss = 1.1455674, step = 2000 (0.164 sec)
# INFO:tensorflow:global_step/sec: 573.086
# INFO:tensorflow:loss = 1.1370318, step = 2100 (0.177 sec)
# INFO:tensorflow:loss = 1.0990398, step = 3700 (0.173 sec)
# INFO:tensorflow:global_step/sec: 611.67
# INFO:tensorflow:loss = 1.0962999, step = 3800 (0.164 sec)
# INFO:tensorflow:global_step/sec: 563.122
# INFO:tensorflow:loss = 1.095829, step = 3900 (0.173 sec)
# INFO:tensorflow:global_step/sec: 604.175
# INFO:tensorflow:loss = 1.1004908, step = 4000 (0.168 sec)
# INFO:tensorflow:global_step/sec: 572.951
# INFO:tensorflow:loss = 1.0934556, step = 4100 (0.175 sec)
# INFO:tensorflow:global_step/sec: 572.675
# INFO:tensorflow:loss = 1.0967488, step = 4200 (0.172 sec)
# INFO:tensorflow:global_step/sec: 610.298
# INFO:tensorflow:loss = 1.0962732, step = 4300 (0.167 sec)
# INFO:tensorflow:global_step/sec: 580.797
# INFO:tensorflow:loss = 1.0957863, step = 4400 (0.169 sec)
# INFO:tensorflow:global_step/sec: 560.143
# INFO:tensorflow:loss = 1.0962616, step = 4500 (0.182 sec)
# INFO:tensorflow:global_step/sec: 589.91
# INFO:tensorflow:loss = 1.0957682, step = 4600 (0.166 sec)
# INFO:tensorflow:global_step/sec: 599.509
# INFO:tensorflow:loss = 1.0947804, step = 4700 (0.168 sec)
# INFO:tensorflow:global_step/sec: 581.621
# INFO:tensorflow:loss = 1.0952617, step = 4800 (0.171 sec)
# INFO:tensorflow:global_step/sec: 613.001
# INFO:tensorflow:loss = 1.0937656, step = 4900 (0.166 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmprzdr9st1/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 1.0957437.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-27T23:51:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmprzdr9st1/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.23393s
# INFO:tensorflow:Finished evaluation at 2021-01-27-23:51:56
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.26666668, average_loss = 1.1174104, global_step = 5000, loss = 1.1174104
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmprzdr9st1/model.ckpt-5000
#
# Test set accuracy: 0.267
#
# {'accuracy': 0.26666668, 'average_loss': 1.1174104, 'loss': 1.1174104, 'global_step': 5000}
#
#
#
# {'accuracy': 0.26666668, 'average_loss': 1.1174104, 'loss': 1.1174104}
# <bound method Estimator.train of <tensorflow_estimator.python.estimator.canned.dnn.DNNClassifierV2 object at 0x7faeb17d1080>>
#
#
#
# <class 'tensorflow.python.ops.losses.loss_reduction.ReductionV2'>
# hidden_units
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpd9auz1ix
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpd9auz1ix', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpd9auz1ix/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.0986121, step = 0
# INFO:tensorflow:global_step/sec: 430.801
# INFO:tensorflow:loss = 1.0981646, step = 100 (0.234 sec)
# INFO:tensorflow:global_step/sec: 614.344
# INFO:tensorflow:loss = 1.0978551, step = 200 (0.162 sec)
# INFO:tensorflow:global_step/sec: 595.997
# INFO:tensorflow:loss = 1.097498, step = 300 (0.168 sec)
# INFO:tensorflow:global_step/sec: 562.315
# INFO:tensorflow:loss = 1.0971341, step = 400 (0.179 sec)
# INFO:tensorflow:global_step/sec: 591.444
# INFO:tensorflow:loss = 1.0960939, step = 500 (0.170 sec)
# INFO:tensorflow:global_step/sec: 572.188
# INFO:tensorflow:loss = 1.097306, step = 600 (0.173 sec)
# INFO:tensorflow:global_step/sec: 576.478
# INFO:tensorflow:loss = 1.0959709, step = 700 (0.174 sec)
# INFO:tensorflow:global_step/sec: 581.474
# INFO:tensorflow:global_step/sec: 567.966
# INFO:tensorflow:loss = 1.0954102, step = 3600 (0.176 sec)
# INFO:tensorflow:global_step/sec: 618.648
# INFO:tensorflow:loss = 1.0935723, step = 3700 (0.164 sec)
# INFO:tensorflow:global_step/sec: 587.518
# INFO:tensorflow:loss = 1.0935392, step = 3800 (0.168 sec)
# INFO:tensorflow:global_step/sec: 619.68
# INFO:tensorflow:loss = 1.0962921, step = 3900 (0.164 sec)
# INFO:tensorflow:global_step/sec: 517.706
# INFO:tensorflow:loss = 1.0958183, step = 4000 (0.194 sec)
# INFO:tensorflow:global_step/sec: 596.455
# INFO:tensorflow:loss = 1.0972226, step = 4100 (0.166 sec)
# INFO:tensorflow:global_step/sec: 564.256
# INFO:tensorflow:loss = 1.0962746, step = 4200 (0.174 sec)
# INFO:tensorflow:global_step/sec: 610.332
# INFO:tensorflow:loss = 1.0962695, step = 4300 (0.164 sec)
# INFO:tensorflow:global_step/sec: 607.393
# INFO:tensorflow:loss = 1.0962648, step = 4400 (0.165 sec)
# INFO:tensorflow:global_step/sec: 547.596
# INFO:tensorflow:loss = 1.0967445, step = 4500 (0.186 sec)
# INFO:tensorflow:global_step/sec: 581.566
# INFO:tensorflow:loss = 1.0957676, step = 4600 (0.168 sec)
# INFO:tensorflow:global_step/sec: 593.42
# INFO:tensorflow:loss = 1.096252, step = 4700 (0.170 sec)
# INFO:tensorflow:global_step/sec: 554.942
# INFO:tensorflow:loss = 1.0947676, step = 4800 (0.186 sec)
# INFO:tensorflow:global_step/sec: 561.869
# INFO:tensorflow:loss = 1.095748, step = 4900 (0.172 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpd9auz1ix/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 1.0942459.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-27T23:52:07Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd9auz1ix/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.25719s
# INFO:tensorflow:Finished evaluation at 2021-01-27-23:52:07
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.26666668, average_loss = 1.1174265, global_step = 5000, loss = 1.1174265
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpd9auz1ix/model.ckpt-5000
#
# Test set accuracy: 0.267
#
# {'accuracy': 0.26666668, 'average_loss': 1.1174265, 'loss': 1.1174265, 'global_step': 5000}
#
#
#
# {'accuracy': 0.26666668, 'average_loss': 1.1174265, 'loss': 1.1174265}
# <bound method Estimator.train of <tensorflow_estimator.python.estimator.canned.dnn.DNNClassifierV2 object at 0x7faeb17d1080>>
#
#
#
# <class 'tensorflow.python.ops.losses.loss_reduction.ReductionV2'>
# hidden_units
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp315pinnn
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp315pinnn', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp315pinnn/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.0986121, step = 0
# INFO:tensorflow:global_step/sec: 454.929
# INFO:tensorflow:loss = 1.0979698, step = 100 (0.226 sec)
# INFO:tensorflow:global_step/sec: 533.004
# INFO:tensorflow:loss = 1.0978581, step = 200 (0.183 sec)
# INFO:tensorflow:global_step/sec: 558.279
# INFO:tensorflow:loss = 1.0982049, step = 300 (0.179 sec)
# INFO:tensorflow:global_step/sec: 519.603
# INFO:tensorflow:loss = 1.0972842, step = 400 (0.196 sec)
# INFO:tensorflow:global_step/sec: 593.812
# INFO:tensorflow:loss = 1.0961035, step = 500 (0.165 sec)
# INFO:tensorflow:global_step/sec: 620.323
# INFO:tensorflow:loss = 1.0969377, step = 600 (0.163 sec)
# INFO:tensorflow:global_step/sec: 611.279
# INFO:tensorflow:loss = 1.0950048, step = 3400 (0.176 sec)
# INFO:tensorflow:global_step/sec: 609.974
# INFO:tensorflow:loss = 1.0949825, step = 3500 (0.162 sec)
# INFO:tensorflow:global_step/sec: 586.967
# INFO:tensorflow:loss = 1.094961, step = 3600 (0.175 sec)
# INFO:tensorflow:global_step/sec: 571.273
# INFO:tensorflow:loss = 1.094941, step = 3700 (0.171 sec)
# INFO:tensorflow:global_step/sec: 598.483
# INFO:tensorflow:loss = 1.0962999, step = 3800 (0.171 sec)
# INFO:tensorflow:global_step/sec: 571.517
# INFO:tensorflow:loss = 1.0953662, step = 3900 (0.171 sec)
# INFO:tensorflow:global_step/sec: 553.542
# INFO:tensorflow:loss = 1.0972207, step = 4000 (0.183 sec)
# INFO:tensorflow:global_step/sec: 561.966
# INFO:tensorflow:loss = 1.0976934, step = 4100 (0.182 sec)
# INFO:tensorflow:global_step/sec: 558.181
# INFO:tensorflow:loss = 1.095801, step = 4200 (0.173 sec)
# INFO:tensorflow:global_step/sec: 573.786
# INFO:tensorflow:loss = 1.095315, step = 4300 (0.174 sec)
# INFO:tensorflow:global_step/sec: 523.347
# INFO:tensorflow:loss = 1.0957842, step = 4400 (0.192 sec)
# INFO:tensorflow:global_step/sec: 591.788
# INFO:tensorflow:loss = 1.0952927, step = 4500 (0.168 sec)
# INFO:tensorflow:global_step/sec: 524.874
# INFO:tensorflow:loss = 1.098207, step = 4600 (0.190 sec)
# INFO:tensorflow:global_step/sec: 541.676
# INFO:tensorflow:loss = 1.0957618, step = 4700 (0.185 sec)
# INFO:tensorflow:global_step/sec: 554.783
# INFO:tensorflow:loss = 1.0967413, step = 4800 (0.186 sec)
# INFO:tensorflow:global_step/sec: 589.178
# INFO:tensorflow:loss = 1.0962453, step = 4900 (0.163 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmp315pinnn/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 1.0947465.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-27T23:52:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp315pinnn/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.22977s
# INFO:tensorflow:Finished evaluation at 2021-01-27-23:52:18
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.26666668, average_loss = 1.1174103, global_step = 5000, loss = 1.1174103
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmp315pinnn/model.ckpt-5000
#
# Test set accuracy: 0.267
#
# {'accuracy': 0.26666668, 'average_loss': 1.1174103, 'loss': 1.1174103, 'global_step': 5000}
#
#
#
# {'accuracy': 0.26666668, 'average_loss': 1.1174103, 'loss': 1.1174103}
# <bound method Estimator.train of <tensorflow_estimator.python.estimator.canned.dnn.DNNClassifierV2 object at 0x7faeb17d1080>>
#
#
#
# <class 'tensorflow.python.ops.losses.loss_reduction.ReductionV2'>
# hidden_units
# Generation 1 ~~ best score = 0.5699999928474426
# #1: [4, 1, 3]; 	score: 0.5699999928474426
# #2: [1, 2, 5]; 	score: 0.4300000071525574
# #3: [5, 2]; 	score: 0.27000001072883606
# #4: [2, 3]; 	score: 0.27000001072883606
# #5: [3, 2, 1]; 	score: 0.27000001072883606
#
# SUCCESS: Target of score of 0.5 was accomplished.
# Top 5 scores:
# #1: [4, 1, 3]; 	score: 0.5699999928474426
# #2: [1, 2, 5]; 	score: 0.4300000071525574
# #3: [5, 2]; 	score: 0.27000001072883606
# #4: [2, 3]; 	score: 0.27000001072883606
# #5: [3, 2, 1]; 	score: 0.27000001072883606
